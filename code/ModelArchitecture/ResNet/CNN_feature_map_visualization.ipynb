# %% [markdown]
# ## CNN Feature Map Visualization

# %% [markdown]
# ### Notebook & Packages

# %%
import helper as hp 
hp.initialize_notebook() # initialize with GPU enabled  
# hp.initialize_notebook(False) # to disable GPU
# Out:
# 2024-12-17 11:59:22.343450: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-17 11:59:22.358019: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-17 11:59:22.362542: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-17 11:59:22.373658: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# GPU enabled. Checking for available GPUs...
# 1 Physical GPUs, 1 Logical GPUs
#
# Verifying TensorFlow and PyTorch CUDA setup...
# TensorFlow version: 2.17.0
# Built with CUDA: True
# Num GPUs Available: 1
#
# Keras version: 3.6.0
#
# End checks and initialization.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1734436764.319135  716392 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1734436764.360633  716392 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1734436764.364167  716392 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1734436764.369296  716392 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1734436764.372726  716392 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1734436764.375967  716392 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1734436764.568667  716392 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1734436764.570688  716392 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1734436764.572554  716392 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-12-17 11:59:24.574363: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13312 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:06.0, compute capability: 7.5

# %%
# Import standard libraries
import os
import sys
import gc
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import time
import keras
# Import DL libraries
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, Dropout # General Layers
from keras.layers import RandomRotation, RandomFlip
from keras import layers, models, Model, Input
from keras.utils import to_categorical
from keras.optimizers import Adam
from keras.callbacks import ReduceLROnPlateau, EarlyStopping, TensorBoard
from keras.initializers import glorot_uniform
from keras.utils import plot_model
# Suppress tensorflow warnings
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# Import ML libraries
from sklearn.metrics import f1_score, confusion_matrix, ConfusionMatrixDisplay
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, StratifiedKFold, StratifiedShuffleSplit
from sklearn.utils.class_weight import compute_class_weight

# Import image libraries
from skimage import transform
import tifffile as tiff
from tifffile import imread

# Appends current working dir
current_path = os.getcwd()
sys.path.append(current_path)

# Import custom preprocessing class
from imc_preprocessing import IMCPreprocessor

# %% [markdown]
# #### Import Data

# %%
images_dir = '/home/jupyter-luvogt/Final_Project_LR/IMC_images' 
metadata_dir = '/home/jupyter-luvogt/Final_Project_LR/metadata.csv'
# --- Load CSV and filter dataset ---
csv_file = metadata_dir
image_folder = images_dir

# Load the CSV
df = pd.read_csv(csv_file)

# Filter rows with NA in PDL1_score and convert to binary
df = df.dropna(subset=["PDL1_score"])
df["PDL1_score"] = df["PDL1_score"].astype(int)

# --- Train-Test-Validation Split ---
train_df, val_and_test_df = train_test_split(df, test_size=0.4, random_state=42, stratify=df["PDL1_score"])
test_df, val_df = train_test_split(val_and_test_df, test_size=0.5, random_state=42, stratify=val_and_test_df["PDL1_score"])

# --- Load Images and Compute Mean and Standard Deviation ---

# Function to load a single image
def load_image(image_path):
    image = imread(image_path)  # Load all 46 channels
    return image.astype(np.float32)

# Initialize variables to accumulate sum and sum of squares
nr_images = 0
sum_images = np.zeros((46, 224, 224))
sum_squared_images = np.zeros((46, 224, 224))

# Accumulate the sum and sum of squares for the training dataset
for _, row in train_df.iterrows():
    image_path = os.path.join(image_folder, f"{row['sample_id']}.tiff")
    image = load_image(image_path)
    nr_images += 1
    sum_images += image
    sum_squared_images += image ** 2

# Compute mean and standard deviation
mean = sum_images / nr_images
std = np.sqrt(sum_squared_images / nr_images - mean ** 2)

# --- Dataset Loading Function ---

def load_dataset(dataframe, image_folder, normalize = True): # augment = False
    images = []
    labels = []
    
    for _, row in dataframe.iterrows():
        image_path = os.path.join(image_folder, f"{row['sample_id']}.tiff")
        image = load_image(image_path)

        if normalize:
            image = (image - mean) / std

        # Convert to channels-last format (224, 224, 46)
        image = np.transpose(image, (1, 2, 0))

        # # Apply data augmentation if specified
        # if augment:
        #     # Random horizontal flip
        #     if np.random.rand() > 0.5:
        #         image = np.flip(image, axis=2)
        #     # Random vertical flip
        #     if np.random.rand() > 0.5:
        #         image = np.flip(image, axis=1)

        images.append(image)
        labels.append(row["PDL1_score"])

    return np.array(images), np.array(labels)

# %% [markdown]
# ### Create Datasets

# %%
# Training dataset without augmentation
X_train, y_train = load_dataset(train_df, image_folder, normalize = True)
# # Training dataset with data augmentation
# X_train_aug, y_train_aug = load_dataset(train_df, image_folder, augment=True)
# Validation dataset
X_val, y_val = load_dataset(val_df, image_folder, normalize = True)
# Test dataset
X_test, y_test = load_dataset(test_df, image_folder, normalize = True)

# One Hot Encoding
y_train= to_categorical(y_train)
y_val= to_categorical(y_val)
y_test = to_categorical(y_test)

print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_val shape: {X_val.shape}, y_val shape: {y_val.shape}")
print(f"X_test shape: {X_test.shape}, y_test shape: {y_test.shape}")
# Out:
# X_train shape: (590, 224, 224, 46), y_train shape: (590, 2)
# X_val shape: (197, 224, 224, 46), y_val shape: (197, 2)
# X_test shape: (197, 224, 224, 46), y_test shape: (197, 2)

# %% [markdown]
# ### Extract last layer before classification

# %%
# Load model 
# To load the model from file uncomment and run the following 
model_ResNet18 = keras.saving.load_model('./models_ResNet/model_ResNet18_46_dropout_callbacks_trained.keras')

# %% [markdown]
# ### Get Layer Names

# %%
layer_names = [layer.name for layer in model_ResNet18.layers]

# %% [markdown]
# We want dense2 layer to be extracted

# %% [markdown]
# ### Get Layer Output

# %%
layer_outputs = [layer.output for layer in model_ResNet18.layers]

# %%
second_last_layer_output = layer_outputs[:-2] # Get all the layers except the last one (disgard the classification layer)

# %% [markdown]
# ### Feature Map Model

# %%
feature_map_model = Model(inputs=model_ResNet18.input, outputs=second_last_layer_output)

# %%
t = feature_map_model.predict(X_test)
# Out:
# I0000 00:00:1734436994.086797  716633 service.cc:146] XLA service 0x7fbc5d01c310 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1734436994.086854  716633 service.cc:154]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2024-12-17 12:03:14.116270: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-12-17 12:03:14.258719: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 90300
# 3/7 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# I0000 00:00:1734436997.756414  716633 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 5/7 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 2024-12-17 12:03:28.165005: W external/local_tsl/tsl/framework/bfc_allocator.cc:482] Allocator (GPU_0_bfc) ran out of memory trying to allocate 341.62MiB (rounded to 358220800)requested by op
# 2024-12-17 12:03:28.165086: I external/local_tsl/tsl/framework/bfc_allocator.cc:1039] BFCAllocator dump for GPU_0_bfc
# 2024-12-17 12:03:28.165096: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (256): 	Total Chunks: 107, Chunks in use: 107. 26.8KiB allocated for chunks. 26.8KiB in use in bin. 14.1KiB client-requested in use in bin.
# 2024-12-17 12:03:28.165102: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (512): 	Total Chunks: 48, Chunks in use: 48. 24.2KiB allocated for chunks. 24.2KiB in use in bin. 24.1KiB client-requested in use in bin.
# 2024-12-17 12:03:28.165107: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (1024): 	Total Chunks: 48, Chunks in use: 48. 48.8KiB allocated for chunks. 48.8KiB in use in bin. 48.0KiB client-requested in use in bin.
# 2024-12-17 12:03:28.165112: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (2048): 	Total Chunks: 50, Chunks in use: 50. 101.2KiB allocated for chunks. 101.2KiB in use in bin. 100.0KiB client-requested in use in bin.
# 2024-12-17 12:03:28.165118: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (4096): 	Total Chunks: 3, Chunks in use: 3. 12.0KiB allocated for chunks. 12.0KiB in use in bin. 12.0KiB client-requested in use in bin.
# 2024-12-17 12:03:28.165123: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (8192): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-12-17 12:03:28.165128: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (16384): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-12-17 12:03:28.165133: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (32768): 	Total Chunks: 4, Chunks in use: 3. 130.0KiB allocated for chunks. 96.0KiB in use in bin. 96.0KiB client-requested in use in bin.
# 2024-12-17 12:03:28.165138: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (65536): 	Total Chunks: 6, Chunks in use: 6. 384.0KiB allocated for chunks. 384.0KiB in use in bin. 384.0KiB client-requested in use in bin.
# 2024-12-17 12:03:28.165143: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (131072): 	Total Chunks: 14, Chunks in use: 14. 2.06MiB allocated for chunks. 2.06MiB in use in bin. 1.92MiB client-requested in use in bin.
# 2024-12-17 12:03:28.165149: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (262144): 	Total Chunks: 3, Chunks in use: 3. 848.8KiB allocated for chunks. 848.8KiB in use in bin. 720.0KiB client-requested in use in bin.
# 2024-12-17 12:03:28.165153: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (524288): 	Total Chunks: 15, Chunks in use: 15. 8.56MiB allocated for chunks. 8.56MiB in use in bin. 7.93MiB client-requested in use in bin.
# 2024-12-17 12:03:28.165159: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (1048576): 	Total Chunks: 16, Chunks in use: 16. 16.47MiB allocated for chunks. 16.47MiB in use in bin. 15.94MiB client-requested in use in bin.
# 2024-12-17 12:03:28.165164: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (2097152): 	Total Chunks: 9, Chunks in use: 9. 21.38MiB allocated for chunks. 21.38MiB in use in bin. 20.25MiB client-requested in use in bin.
# 2024-12-17 12:03:28.165169: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (4194304): 	Total Chunks: 206, Chunks in use: 206. 1.10GiB allocated for chunks. 1.10GiB in use in bin. 1.10GiB client-requested in use in bin.
# 2024-12-17 12:03:28.165174: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (8388608): 	Total Chunks: 111, Chunks in use: 111. 1.38GiB allocated for chunks. 1.38GiB in use in bin. 1.38GiB client-requested in use in bin.
# 2024-12-17 12:03:28.165179: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (16777216): 	Total Chunks: 106, Chunks in use: 106. 2.69GiB allocated for chunks. 2.69GiB in use in bin. 2.68GiB client-requested in use in bin.
# 2024-12-17 12:03:28.165183: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (33554432): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-12-17 12:03:28.165191: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (67108864): 	Total Chunks: 24, Chunks in use: 24. 2.42GiB allocated for chunks. 2.42GiB in use in bin. 2.42GiB client-requested in use in bin.
# 2024-12-17 12:03:28.165195: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (134217728): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-12-17 12:03:28.165200: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (268435456): 	Total Chunks: 14, Chunks in use: 13. 5.35GiB allocated for chunks. 5.08GiB in use in bin. 5.08GiB client-requested in use in bin.
# 2024-12-17 12:03:28.165205: I external/local_tsl/tsl/framework/bfc_allocator.cc:1062] Bin for 341.63MiB was 256.00MiB, Chunk State:
# 2024-12-17 12:03:28.165218: I external/local_tsl/tsl/framework/bfc_allocator.cc:1068]   Size: 268.81MiB | Requested Size: 0B | in_use: 0 | bin_num: 20, prev:   Size: 64.0KiB | Requested Size: 64.0KiB | in_use: 1 | bin_num: -1
# 2024-12-17 12:03:28.165222: I external/local_tsl/tsl/framework/bfc_allocator.cc:1075] Next region of size 13958643712
# 2024-12-17 12:03:28.165227: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4000000 of size 256 next 1
# 2024-12-17 12:03:28.165231: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4000100 of size 1280 next 2
# 2024-12-17 12:03:28.165234: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4000600 of size 256 next 3
# 2024-12-17 12:03:28.165237: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4000700 of size 256 next 4
# 2024-12-17 12:03:28.165241: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4000800 of size 256 next 5
# 2024-12-17 12:03:28.165244: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4000900 of size 256 next 7
# 2024-12-17 12:03:28.165247: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4000a00 of size 256 next 8
# 2024-12-17 12:03:28.165250: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4000b00 of size 256 next 6
# 2024-12-17 12:03:28.165254: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4000c00 of size 256 next 9
# 2024-12-17 12:03:28.165257: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4000d00 of size 256 next 12
# 2024-12-17 12:03:28.165260: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4000e00 of size 256 next 13
# 2024-12-17 12:03:28.165264: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4000f00 of size 256 next 14
# 2024-12-17 12:03:28.165267: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4001000 of size 256 next 15
# 2024-12-17 12:03:28.165270: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4001100 of size 256 next 16
# 2024-12-17 12:03:28.165273: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4001200 of size 256 next 17
# 2024-12-17 12:03:28.165276: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4001300 of size 256 next 19
# 2024-12-17 12:03:28.165280: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4001400 of size 256 next 20
# 2024-12-17 12:03:28.165283: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4001500 of size 256 next 18
# 2024-12-17 12:03:28.165286: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4001600 of size 256 next 21
# 2024-12-17 12:03:28.165289: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4001700 of size 256 next 24
# 2024-12-17 12:03:28.165293: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4001800 of size 32768 next 220
# 2024-12-17 12:03:28.165296: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4009800 of size 2048 next 274
# 2024-12-17 12:03:28.165301: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d400a000 of size 2048 next 275
# 2024-12-17 12:03:28.165305: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d400a800 of size 2048 next 276
# 2024-12-17 12:03:28.165308: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d400b000 of size 2048 next 277
# 2024-12-17 12:03:28.165311: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d400b800 of size 2048 next 160
# 2024-12-17 12:03:28.165314: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d400c000 of size 2048 next 279
# 2024-12-17 12:03:28.165318: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d400c800 of size 2048 next 281
# 2024-12-17 12:03:28.165321: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d400d000 of size 2048 next 282
# 2024-12-17 12:03:28.165324: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d400d800 of size 2048 next 283
# 2024-12-17 12:03:28.165327: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d400e000 of size 2048 next 284
# 2024-12-17 12:03:28.165331: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d400e800 of size 2048 next 287
# 2024-12-17 12:03:28.165334: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d400f000 of size 2048 next 286
# 2024-12-17 12:03:28.165337: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d400f800 of size 2048 next 291
# 2024-12-17 12:03:28.165340: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4010000 of size 2048 next 290
# 2024-12-17 12:03:28.165344: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4010800 of size 2048 next 293
# 2024-12-17 12:03:28.165347: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4011000 of size 2048 next 294
# 2024-12-17 12:03:28.165350: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4011800 of size 2048 next 295
# 2024-12-17 12:03:28.165353: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4012000 of size 2048 next 292
# 2024-12-17 12:03:28.165357: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4012800 of size 2048 next 298
# 2024-12-17 12:03:28.165360: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4013000 of size 2048 next 299
# 2024-12-17 12:03:28.165363: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4013800 of size 2048 next 300
# 2024-12-17 12:03:28.165367: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4014000 of size 2048 next 301
# 2024-12-17 12:03:28.165370: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4014800 of size 2048 next 302
# 2024-12-17 12:03:28.165373: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4015000 of size 2048 next 303
# 2024-12-17 12:03:28.165376: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4015800 of size 2048 next 304
# 2024-12-17 12:03:28.165380: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4016000 of size 2048 next 307
# 2024-12-17 12:03:28.165383: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4016800 of size 4096 next 308
# 2024-12-17 12:03:28.165387: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4017800 of size 4096 next 309
# 2024-12-17 12:03:28.165390: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4018800 of size 256 next 310
# 2024-12-17 12:03:28.165394: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4018900 of size 256 next 311
# 2024-12-17 12:03:28.165397: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4018a00 of size 256 next 312
# 2024-12-17 12:03:28.165400: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4018b00 of size 256 next 278
# 2024-12-17 12:03:28.165403: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4018c00 of size 256 next 244
# 2024-12-17 12:03:28.165407: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4018d00 of size 768 next 783
# 2024-12-17 12:03:28.165410: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] Free  at 7fb4d4019000 of size 34816 next 107
# 2024-12-17 12:03:28.165414: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4021800 of size 163328 next 22
# 2024-12-17 12:03:28.165418: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4049600 of size 147456 next 23
# 2024-12-17 12:03:28.165421: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d406d600 of size 256 next 26
# 2024-12-17 12:03:28.165425: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d406d700 of size 256 next 27
# 2024-12-17 12:03:28.165428: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d406d800 of size 256 next 25
# 2024-12-17 12:03:28.165432: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d406d900 of size 256 next 28
# 2024-12-17 12:03:28.165435: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d406da00 of size 256 next 31
# 2024-12-17 12:03:28.165438: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d406db00 of size 256 next 33
# 2024-12-17 12:03:28.165442: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d406dc00 of size 256 next 34
# 2024-12-17 12:03:28.165445: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d406dd00 of size 256 next 32
# 2024-12-17 12:03:28.165449: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d406de00 of size 256 next 35
# 2024-12-17 12:03:28.165452: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d406df00 of size 256 next 37
# 2024-12-17 12:03:28.165455: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d406e000 of size 256 next 38
# 2024-12-17 12:03:28.165459: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d406e100 of size 256 next 40
# 2024-12-17 12:03:28.165462: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d406e200 of size 256 next 41
# 2024-12-17 12:03:28.165465: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d406e300 of size 256 next 39
# 2024-12-17 12:03:28.165469: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d406e400 of size 256 next 43
# 2024-12-17 12:03:28.165472: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d406e500 of size 256 next 44
# 2024-12-17 12:03:28.165475: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d406e600 of size 256 next 45
# 2024-12-17 12:03:28.165479: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d406e700 of size 256 next 46
# 2024-12-17 12:03:28.165482: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d406e800 of size 512 next 47
# 2024-12-17 12:03:28.165486: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d406ea00 of size 512 next 50
# 2024-12-17 12:03:28.165489: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d406ec00 of size 512 next 48
# 2024-12-17 12:03:28.165492: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d406ee00 of size 512 next 49
# 2024-12-17 12:03:28.165495: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d406f000 of size 512 next 53
# 2024-12-17 12:03:28.165499: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d406f200 of size 256 next 54
# 2024-12-17 12:03:28.165502: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d406f300 of size 256 next 55
# 2024-12-17 12:03:28.165505: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d406f400 of size 256 next 56
# 2024-12-17 12:03:28.165510: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d406f500 of size 512 next 57
# 2024-12-17 12:03:28.165513: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d406f700 of size 512 next 58
# 2024-12-17 12:03:28.165516: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d406f900 of size 512 next 59
# 2024-12-17 12:03:28.165520: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d406fb00 of size 512 next 62
# 2024-12-17 12:03:28.165523: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d406fd00 of size 512 next 63
# 2024-12-17 12:03:28.165526: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d406ff00 of size 256 next 64
# 2024-12-17 12:03:28.165529: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4070000 of size 256 next 65
# 2024-12-17 12:03:28.165533: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4070100 of size 2048 next 121
# 2024-12-17 12:03:28.165536: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4070900 of size 2048 next 122
# 2024-12-17 12:03:28.165539: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4071100 of size 256 next 126
# 2024-12-17 12:03:28.165542: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4071200 of size 256 next 127
# 2024-12-17 12:03:28.165546: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4071300 of size 256 next 128
# 2024-12-17 12:03:28.165549: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4071400 of size 2048 next 129
# 2024-12-17 12:03:28.165552: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4071c00 of size 2048 next 130
# 2024-12-17 12:03:28.165555: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4072400 of size 2048 next 131
# 2024-12-17 12:03:28.165559: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4072c00 of size 2048 next 134
# 2024-12-17 12:03:28.165562: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4073400 of size 2048 next 135
# 2024-12-17 12:03:28.165565: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4073c00 of size 256 next 136
# 2024-12-17 12:03:28.165568: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4073d00 of size 256 next 137
# 2024-12-17 12:03:28.165572: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4073e00 of size 2048 next 138
# 2024-12-17 12:03:28.165575: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4074600 of size 2048 next 140
# 2024-12-17 12:03:28.165578: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4074e00 of size 2048 next 142
# 2024-12-17 12:03:28.165581: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4075600 of size 2048 next 139
# 2024-12-17 12:03:28.165585: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4075e00 of size 2048 next 144
# 2024-12-17 12:03:28.165588: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4076600 of size 2048 next 145
# 2024-12-17 12:03:28.165591: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4076e00 of size 256 next 146
# 2024-12-17 12:03:28.165594: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4076f00 of size 2048 next 148
# 2024-12-17 12:03:28.165597: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4077700 of size 2048 next 149
# 2024-12-17 12:03:28.165601: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4077f00 of size 2048 next 147
# 2024-12-17 12:03:28.165604: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4078700 of size 2048 next 151
# 2024-12-17 12:03:28.165607: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4078f00 of size 2048 next 152
# 2024-12-17 12:03:28.165612: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4079700 of size 256 next 153
# 2024-12-17 12:03:28.165615: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4079800 of size 256 next 154
# 2024-12-17 12:03:28.165618: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4079900 of size 512 next 206
# 2024-12-17 12:03:28.165621: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4079b00 of size 512 next 207
# 2024-12-17 12:03:28.165625: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4079d00 of size 512 next 208
# 2024-12-17 12:03:28.165628: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4079f00 of size 512 next 155
# 2024-12-17 12:03:28.165631: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d407a100 of size 256 next 158
# 2024-12-17 12:03:28.165634: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d407a200 of size 256 next 156
# 2024-12-17 12:03:28.165638: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d407a300 of size 256 next 157
# 2024-12-17 12:03:28.165641: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d407a400 of size 256 next 161
# 2024-12-17 12:03:28.165644: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d407a500 of size 256 next 163
# 2024-12-17 12:03:28.165647: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d407a600 of size 256 next 164
# 2024-12-17 12:03:28.165651: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d407a700 of size 256 next 162
# 2024-12-17 12:03:28.165654: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d407a800 of size 256 next 165
# 2024-12-17 12:03:28.165657: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d407a900 of size 256 next 168
# 2024-12-17 12:03:28.165660: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d407aa00 of size 256 next 169
# 2024-12-17 12:03:28.165664: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d407ab00 of size 256 next 170
# 2024-12-17 12:03:28.165667: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d407ac00 of size 256 next 171
# 2024-12-17 12:03:28.165670: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d407ad00 of size 256 next 172
# 2024-12-17 12:03:28.165673: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d407ae00 of size 256 next 173
# 2024-12-17 12:03:28.165676: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d407af00 of size 256 next 174
# 2024-12-17 12:03:28.165680: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d407b000 of size 256 next 176
# 2024-12-17 12:03:28.165683: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d407b100 of size 256 next 177
# 2024-12-17 12:03:28.165686: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d407b200 of size 256 next 178
# 2024-12-17 12:03:28.165689: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d407b300 of size 256 next 179
# 2024-12-17 12:03:28.165693: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d407b400 of size 256 next 180
# 2024-12-17 12:03:28.165696: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d407b500 of size 256 next 181
# 2024-12-17 12:03:28.165699: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d407b600 of size 256 next 184
# 2024-12-17 12:03:28.165702: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d407b700 of size 256 next 185
# 2024-12-17 12:03:28.165706: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d407b800 of size 256 next 186
# 2024-12-17 12:03:28.165709: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d407b900 of size 256 next 187
# 2024-12-17 12:03:28.165713: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d407ba00 of size 256 next 188
# 2024-12-17 12:03:28.165717: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d407bb00 of size 256 next 189
# 2024-12-17 12:03:28.165720: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d407bc00 of size 256 next 192
# 2024-12-17 12:03:28.165723: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d407bd00 of size 256 next 193
# 2024-12-17 12:03:28.165726: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d407be00 of size 256 next 194
# 2024-12-17 12:03:28.165730: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d407bf00 of size 256 next 195
# 2024-12-17 12:03:28.165733: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d407c000 of size 256 next 196
# 2024-12-17 12:03:28.165736: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d407c100 of size 256 next 197
# 2024-12-17 12:03:28.165739: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d407c200 of size 256 next 200
# 2024-12-17 12:03:28.165742: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d407c300 of size 256 next 201
# 2024-12-17 12:03:28.165746: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d407c400 of size 256 next 202
# 2024-12-17 12:03:28.165749: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d407c500 of size 256 next 203
# 2024-12-17 12:03:28.165752: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d407c600 of size 256 next 204
# 2024-12-17 12:03:28.165755: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d407c700 of size 512 next 209
# 2024-12-17 12:03:28.165759: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d407c900 of size 512 next 211
# 2024-12-17 12:03:28.165763: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d407cb00 of size 512 next 214
# 2024-12-17 12:03:28.165766: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d407cd00 of size 512 next 215
# 2024-12-17 12:03:28.165769: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d407cf00 of size 512 next 216
# 2024-12-17 12:03:28.165772: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d407d100 of size 512 next 217
# 2024-12-17 12:03:28.165776: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d407d300 of size 512 next 167
# 2024-12-17 12:03:28.165779: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d407d500 of size 512 next 219
# 2024-12-17 12:03:28.165782: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d407d700 of size 512 next 224
# 2024-12-17 12:03:28.165785: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d407d900 of size 512 next 223
# 2024-12-17 12:03:28.165789: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d407db00 of size 512 next 225
# 2024-12-17 12:03:28.165792: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d407dd00 of size 512 next 226
# 2024-12-17 12:03:28.165795: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d407df00 of size 512 next 227
# 2024-12-17 12:03:28.165798: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d407e100 of size 512 next 228
# 2024-12-17 12:03:28.165802: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d407e300 of size 512 next 231
# 2024-12-17 12:03:28.165805: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d407e500 of size 512 next 230
# 2024-12-17 12:03:28.165808: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d407e700 of size 512 next 233
# 2024-12-17 12:03:28.165812: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d407e900 of size 512 next 221
# 2024-12-17 12:03:28.165816: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d407eb00 of size 512 next 234
# 2024-12-17 12:03:28.165819: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d407ed00 of size 512 next 235
# 2024-12-17 12:03:28.165823: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d407ef00 of size 1024 next 238
# 2024-12-17 12:03:28.165826: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d407f300 of size 1024 next 237
# 2024-12-17 12:03:28.165830: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d407f700 of size 1024 next 240
# 2024-12-17 12:03:28.165833: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d407fb00 of size 1024 next 241
# 2024-12-17 12:03:28.165837: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d407ff00 of size 1536 next 71
# 2024-12-17 12:03:28.165840: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4080500 of size 512 next 72
# 2024-12-17 12:03:28.165843: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4080700 of size 512 next 66
# 2024-12-17 12:03:28.165847: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4080900 of size 512 next 69
# 2024-12-17 12:03:28.165850: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4080b00 of size 512 next 67
# 2024-12-17 12:03:28.165853: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4080d00 of size 512 next 68
# 2024-12-17 12:03:28.165857: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4080f00 of size 512 next 73
# 2024-12-17 12:03:28.165860: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4081100 of size 1024 next 320
# 2024-12-17 12:03:28.165863: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4081500 of size 2048 next 323
# 2024-12-17 12:03:28.165866: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4081d00 of size 4096 next 326
# 2024-12-17 12:03:28.165870: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4082d00 of size 1024 next 243
# 2024-12-17 12:03:28.165873: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4083100 of size 1024 next 125
# 2024-12-17 12:03:28.165876: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4083500 of size 1024 next 245
# 2024-12-17 12:03:28.165880: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4083900 of size 1024 next 247
# 2024-12-17 12:03:28.165883: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4083d00 of size 1024 next 248
# 2024-12-17 12:03:28.165886: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4084100 of size 1024 next 249
# 2024-12-17 12:03:28.165890: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4084500 of size 1024 next 250
# 2024-12-17 12:03:28.165893: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4084900 of size 1024 next 253
# 2024-12-17 12:03:28.165896: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4084d00 of size 1024 next 252
# 2024-12-17 12:03:28.165900: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4085100 of size 1024 next 257
# 2024-12-17 12:03:28.165903: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4085500 of size 1024 next 256
# 2024-12-17 12:03:28.165906: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4085900 of size 1024 next 259
# 2024-12-17 12:03:28.165910: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4085d00 of size 1024 next 260
# 2024-12-17 12:03:28.165913: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4086100 of size 1024 next 261
# 2024-12-17 12:03:28.165916: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4086500 of size 1024 next 262
# 2024-12-17 12:03:28.165920: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4086900 of size 1024 next 150
# 2024-12-17 12:03:28.165923: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4086d00 of size 1024 next 264
# 2024-12-17 12:03:28.165926: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4087100 of size 1024 next 266
# 2024-12-17 12:03:28.165930: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4087500 of size 1024 next 267
# 2024-12-17 12:03:28.165933: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4087900 of size 1024 next 268
# 2024-12-17 12:03:28.165936: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4087d00 of size 1024 next 269
# 2024-12-17 12:03:28.165939: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4088100 of size 2048 next 272
# 2024-12-17 12:03:28.165943: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4088900 of size 2048 next 74
# 2024-12-17 12:03:28.165946: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4089100 of size 256 next 75
# 2024-12-17 12:03:28.165949: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4089200 of size 512 next 77
# 2024-12-17 12:03:28.165953: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4089400 of size 512 next 78
# 2024-12-17 12:03:28.165956: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4089600 of size 512 next 76
# 2024-12-17 12:03:28.165959: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4089800 of size 512 next 80
# 2024-12-17 12:03:28.165963: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4089a00 of size 256 next 327
# 2024-12-17 12:03:28.165966: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4089b00 of size 256 next 81
# 2024-12-17 12:03:28.165969: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4089c00 of size 256 next 82
# 2024-12-17 12:03:28.165973: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4089d00 of size 256 next 83
# 2024-12-17 12:03:28.165976: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4089e00 of size 1024 next 84
# 2024-12-17 12:03:28.165979: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d408a200 of size 1024 next 87
# 2024-12-17 12:03:28.165982: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d408a600 of size 1024 next 85
# 2024-12-17 12:03:28.165986: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d408aa00 of size 1024 next 86
# 2024-12-17 12:03:28.165989: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d408ae00 of size 1024 next 90
# 2024-12-17 12:03:28.165992: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d408b200 of size 256 next 91
# 2024-12-17 12:03:28.165996: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d408b300 of size 256 next 92
# 2024-12-17 12:03:28.165999: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d408b400 of size 256 next 93
# 2024-12-17 12:03:28.166002: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d408b500 of size 1024 next 94
# 2024-12-17 12:03:28.166006: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d408b900 of size 1024 next 95
# 2024-12-17 12:03:28.166009: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d408bd00 of size 1024 next 96
# 2024-12-17 12:03:28.166012: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d408c100 of size 1024 next 99
# 2024-12-17 12:03:28.166015: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d408c500 of size 1024 next 100
# 2024-12-17 12:03:28.166019: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d408c900 of size 256 next 101
# 2024-12-17 12:03:28.166022: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d408ca00 of size 256 next 102
# 2024-12-17 12:03:28.166025: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d408cb00 of size 1024 next 103
# 2024-12-17 12:03:28.166029: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d408cf00 of size 1024 next 105
# 2024-12-17 12:03:28.166032: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d408d300 of size 1024 next 106
# 2024-12-17 12:03:28.166035: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d408d700 of size 1024 next 104
# 2024-12-17 12:03:28.166039: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d408db00 of size 1024 next 109
# 2024-12-17 12:03:28.166042: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d408df00 of size 1024 next 110
# 2024-12-17 12:03:28.166045: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d408e300 of size 256 next 111
# 2024-12-17 12:03:28.166048: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d408e400 of size 1024 next 113
# 2024-12-17 12:03:28.166052: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d408e800 of size 1024 next 114
# 2024-12-17 12:03:28.166055: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d408ec00 of size 1024 next 112
# 2024-12-17 12:03:28.166058: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d408f000 of size 1024 next 116
# 2024-12-17 12:03:28.166061: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d408f400 of size 512 next 205
# 2024-12-17 12:03:28.166065: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d408f600 of size 512 next 117
# 2024-12-17 12:03:28.166068: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d408f800 of size 256 next 118
# 2024-12-17 12:03:28.166072: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d408f900 of size 256 next 119
# 2024-12-17 12:03:28.166075: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d408fa00 of size 2048 next 120
# 2024-12-17 12:03:28.166079: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4090200 of size 2048 next 123
# 2024-12-17 12:03:28.166082: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4090a00 of size 3328 next 29
# 2024-12-17 12:03:28.166085: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4091700 of size 147456 next 30
# 2024-12-17 12:03:28.166089: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d40b5700 of size 147456 next 36
# 2024-12-17 12:03:28.166092: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d40d9700 of size 266496 next 10
# 2024-12-17 12:03:28.166096: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d411a800 of size 256 next 315
# 2024-12-17 12:03:28.166099: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d411a900 of size 147456 next 316
# 2024-12-17 12:03:28.166102: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d413e900 of size 576768 next 42
# 2024-12-17 12:03:28.166106: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d41cb600 of size 589824 next 52
# 2024-12-17 12:03:28.166109: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d425b600 of size 512 next 11
# 2024-12-17 12:03:28.166112: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d425b800 of size 32768 next 318
# 2024-12-17 12:03:28.166116: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4263800 of size 261632 next 51
# 2024-12-17 12:03:28.166119: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d42a3600 of size 147456 next 141
# 2024-12-17 12:03:28.166123: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d42c7600 of size 147456 next 175
# 2024-12-17 12:03:28.166126: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d42eb600 of size 147456 next 182
# 2024-12-17 12:03:28.166129: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d430f600 of size 147456 next 61
# 2024-12-17 12:03:28.166132: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4333600 of size 589824 next 60
# 2024-12-17 12:03:28.166136: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d43c3600 of size 589824 next 70
# 2024-12-17 12:03:28.166139: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4453600 of size 589824 next 79
# 2024-12-17 12:03:28.166142: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d44e3600 of size 294912 next 199
# 2024-12-17 12:03:28.166146: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d452b600 of size 589824 next 210
# 2024-12-17 12:03:28.166149: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d45bb600 of size 589824 next 222
# 2024-12-17 12:03:28.166152: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d464b600 of size 884736 next 89
# 2024-12-17 12:03:28.166156: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4723600 of size 577024 next 328
# 2024-12-17 12:03:28.166159: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d47b0400 of size 147456 next 190
# 2024-12-17 12:03:28.166163: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d47d4400 of size 147456 next 191
# 2024-12-17 12:03:28.166166: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d47f8400 of size 307712 next 88
# 2024-12-17 12:03:28.166169: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4843600 of size 589824 next 212
# 2024-12-17 12:03:28.166173: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d48d3600 of size 32768 next 218
# 2024-12-17 12:03:28.166176: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d48db600 of size 589824 next 229
# 2024-12-17 12:03:28.166179: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d496b600 of size 1146880 next 98
# 2024-12-17 12:03:28.166183: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4a83600 of size 2359296 next 97
# 2024-12-17 12:03:28.166186: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4cc3600 of size 2359296 next 108
# 2024-12-17 12:03:28.166190: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d4f03600 of size 1179648 next 236
# 2024-12-17 12:03:28.166193: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d5023600 of size 1179648 next 232
# 2024-12-17 12:03:28.166196: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d5143600 of size 3538944 next 239
# 2024-12-17 12:03:28.166200: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d54a3600 of size 2359296 next 246
# 2024-12-17 12:03:28.166203: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d56e3600 of size 131072 next 251
# 2024-12-17 12:03:28.166207: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d5703600 of size 131072 next 124
# 2024-12-17 12:03:28.166210: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d5723600 of size 2359296 next 255
# 2024-12-17 12:03:28.166213: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d5963600 of size 2359296 next 254
# 2024-12-17 12:03:28.166216: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d5ba3600 of size 2359296 next 263
# 2024-12-17 12:03:28.166220: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d5de3600 of size 524288 next 285
# 2024-12-17 12:03:28.166223: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d5e63600 of size 524288 next 159
# 2024-12-17 12:03:28.166227: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d5ee3600 of size 9306112 next 133
# 2024-12-17 12:03:28.166230: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d67c3600 of size 9437184 next 132
# 2024-12-17 12:03:28.166234: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d70c3600 of size 9437184 next 143
# 2024-12-17 12:03:28.166237: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d79c3600 of size 2359296 next 258
# 2024-12-17 12:03:28.166241: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d7c03600 of size 4718592 next 270
# 2024-12-17 12:03:28.166244: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d8083600 of size 4718592 next 265
# 2024-12-17 12:03:28.166247: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d8503600 of size 9437184 next 273
# 2024-12-17 12:03:28.166251: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d8e03600 of size 9437184 next 280
# 2024-12-17 12:03:28.166254: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4d9703600 of size 9437184 next 289
# 2024-12-17 12:03:28.166257: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4da003600 of size 9437184 next 288
# 2024-12-17 12:03:28.166260: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4da903600 of size 9437184 next 296
# 2024-12-17 12:03:28.166264: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4db203600 of size 9437184 next 297
# 2024-12-17 12:03:28.166267: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4dbb03600 of size 30162944 next 305
# 2024-12-17 12:03:28.166271: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4dd7c7600 of size 16777216 next 306
# 2024-12-17 12:03:28.166274: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4de7c7600 of size 16790016 next 313
# 2024-12-17 12:03:28.166277: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4df7ca800 of size 577024 next 314
# 2024-12-17 12:03:28.166281: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4df857600 of size 589824 next 317
# 2024-12-17 12:03:28.166284: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4df8e7600 of size 1179648 next 319
# 2024-12-17 12:03:28.166287: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4dfa07600 of size 2359296 next 321
# 2024-12-17 12:03:28.166290: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb4dfc47600 of size 4718592 next 322
# ...
# 2024-12-17 12:03:28.167737: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb7f9fc7e00 of size 7372800 next 752
# 2024-12-17 12:03:28.167740: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb7fa6cfe00 of size 7372800 next 753
# 2024-12-17 12:03:28.167743: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb7fadd7e00 of size 7372800 next 754
# 2024-12-17 12:03:28.167746: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb7fb4dfe00 of size 7372800 next 755
# 2024-12-17 12:03:28.167749: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb7fbbe7e00 of size 7372800 next 756
# 2024-12-17 12:03:28.167753: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb7fc2efe00 of size 7372800 next 757
# 2024-12-17 12:03:28.167756: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb7fc9f7e00 of size 7372800 next 758
# 2024-12-17 12:03:28.167759: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb7fd0ffe00 of size 7372800 next 759
# 2024-12-17 12:03:28.167762: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb7fd807e00 of size 7372800 next 760
# 2024-12-17 12:03:28.167765: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb7fdf0fe00 of size 7372800 next 761
# 2024-12-17 12:03:28.167769: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb7fe617e00 of size 7372800 next 762
# 2024-12-17 12:03:28.167772: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb7fed1fe00 of size 4194304 next 763
# 2024-12-17 12:03:28.167775: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb7ff11fe00 of size 4194304 next 764
# 2024-12-17 12:03:28.167778: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb7ff51fe00 of size 4194304 next 765
# 2024-12-17 12:03:28.167782: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb7ff91fe00 of size 4194304 next 766
# 2024-12-17 12:03:28.167785: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb7ffd1fe00 of size 4194304 next 767
# 2024-12-17 12:03:28.167788: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb80011fe00 of size 4194304 next 768
# 2024-12-17 12:03:28.167791: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb80051fe00 of size 4194304 next 769
# 2024-12-17 12:03:28.167795: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb80091fe00 of size 4194304 next 770
# 2024-12-17 12:03:28.167798: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb800d1fe00 of size 4194304 next 771
# 2024-12-17 12:03:28.167801: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb80111fe00 of size 4194304 next 772
# 2024-12-17 12:03:28.167804: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb80151fe00 of size 4194304 next 773
# 2024-12-17 12:03:28.167807: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb80191fe00 of size 4194304 next 774
# 2024-12-17 12:03:28.167811: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb801d1fe00 of size 4194304 next 775
# 2024-12-17 12:03:28.167814: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb80211fe00 of size 4194304 next 776
# 2024-12-17 12:03:28.167817: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb80251fe00 of size 4194304 next 777
# 2024-12-17 12:03:28.167820: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb80291fe00 of size 4194304 next 778
# 2024-12-17 12:03:28.167824: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb802d1fe00 of size 4194304 next 779
# 2024-12-17 12:03:28.167827: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb80311fe00 of size 1048576 next 780
# 2024-12-17 12:03:28.167830: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb80321fe00 of size 1048576 next 781
# 2024-12-17 12:03:28.167833: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb80331fe00 of size 65536 next 782
# 2024-12-17 12:03:28.167837: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] Free  at 7fb80332fe00 of size 281870848 next 18446744073709551615
# 2024-12-17 12:03:28.167840: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100]      Summary of in-use Chunks by size:
# 2024-12-17 12:03:28.167846: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 107 Chunks of size 256 totalling 26.8KiB
# 2024-12-17 12:03:28.167850: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 47 Chunks of size 512 totalling 23.5KiB
# 2024-12-17 12:03:28.167854: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 768 totalling 768B
# 2024-12-17 12:03:28.167857: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 46 Chunks of size 1024 totalling 46.0KiB
# 2024-12-17 12:03:28.167861: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 1280 totalling 1.2KiB
# 2024-12-17 12:03:28.167865: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 1536 totalling 1.5KiB
# 2024-12-17 12:03:28.167869: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 49 Chunks of size 2048 totalling 98.0KiB
# 2024-12-17 12:03:28.167873: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 3328 totalling 3.2KiB
# 2024-12-17 12:03:28.167877: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 3 Chunks of size 4096 totalling 12.0KiB
# 2024-12-17 12:03:28.167881: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 3 Chunks of size 32768 totalling 96.0KiB
# 2024-12-17 12:03:28.167884: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 6 Chunks of size 65536 totalling 384.0KiB
# 2024-12-17 12:03:28.167888: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 131072 totalling 256.0KiB
# 2024-12-17 12:03:28.167892: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 10 Chunks of size 147456 totalling 1.41MiB
# 2024-12-17 12:03:28.167896: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 163328 totalling 159.5KiB
# 2024-12-17 12:03:28.167900: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 261632 totalling 255.5KiB
# 2024-12-17 12:03:28.167904: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 266496 totalling 260.2KiB
# 2024-12-17 12:03:28.167908: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 294912 totalling 288.0KiB
# 2024-12-17 12:03:28.167911: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 307712 totalling 300.5KiB
# 2024-12-17 12:03:28.167915: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 524288 totalling 1.00MiB
# 2024-12-17 12:03:28.167919: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 576768 totalling 563.2KiB
# 2024-12-17 12:03:28.167923: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 577024 totalling 1.10MiB
# 2024-12-17 12:03:28.167927: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 9 Chunks of size 589824 totalling 5.06MiB
# 2024-12-17 12:03:28.167930: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 884736 totalling 864.0KiB
# 2024-12-17 12:03:28.167934: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 12 Chunks of size 1048576 totalling 12.00MiB
# 2024-12-17 12:03:28.167938: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 1146880 totalling 1.09MiB
# 2024-12-17 12:03:28.167942: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 3 Chunks of size 1179648 totalling 3.38MiB
# 2024-12-17 12:03:28.167946: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 8 Chunks of size 2359296 totalling 18.00MiB
# 2024-12-17 12:03:28.167950: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 3538944 totalling 3.38MiB
# 2024-12-17 12:03:28.167953: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 102 Chunks of size 4194304 totalling 408.00MiB
# 2024-12-17 12:03:28.167957: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 3 Chunks of size 4718592 totalling 13.50MiB
# 2024-12-17 12:03:28.167961: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 101 Chunks of size 7372800 totalling 710.16MiB
# 2024-12-17 12:03:28.167965: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 9306112 totalling 8.88MiB
# 2024-12-17 12:03:28.167969: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 9 Chunks of size 9437184 totalling 81.00MiB
# 2024-12-17 12:03:28.167973: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 101 Chunks of size 13778944 totalling 1.30GiB
# 2024-12-17 12:03:28.167977: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 16777216 totalling 32.00MiB
# 2024-12-17 12:03:28.167981: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 16790016 totalling 16.01MiB
# 2024-12-17 12:03:28.167984: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 102 Chunks of size 27557888 totalling 2.62GiB
# 2024-12-17 12:03:28.167988: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 30162944 totalling 28.77MiB
# 2024-12-17 12:03:28.167992: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 24 Chunks of size 108339200 totalling 2.42GiB
# 2024-12-17 12:03:28.167996: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 6 Chunks of size 295436288 totalling 1.65GiB
# 2024-12-17 12:03:28.168000: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 6 Chunks of size 311475200 totalling 1.74GiB
# 2024-12-17 12:03:28.168003: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 1818779648 totalling 1.69GiB
# 2024-12-17 12:03:28.168007: I external/local_tsl/tsl/framework/bfc_allocator.cc:1107] Sum Total of in-use chunks: 12.74GiB
# 2024-12-17 12:03:28.168011: I external/local_tsl/tsl/framework/bfc_allocator.cc:1109] Total bytes in pool: 13958643712 memory_limit_: 13958643712 available bytes: 0 curr_region_allocation_bytes_: 27917287424
# 2024-12-17 12:03:28.168019: I external/local_tsl/tsl/framework/bfc_allocator.cc:1114] Stats:
# Limit:                     13958643712
# InUse:                     13676738048
# MaxInUse:                  13676738048
# NumAllocs:                        1425
# MaxAllocSize:               3832348416
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2024-12-17 12:03:28.168038: W external/local_tsl/tsl/framework/bfc_allocator.cc:494] **************************************************************************************************__
# 2024-12-17 12:03:28.168167: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 358220648 bytes.
# 	 [[{{node StatefulPartitionedCall}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 t = feature_map_model.predict(X_test)
#
# File /opt/tljh/user/envs/BME342_GPU_env/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File /opt/tljh/user/envs/BME342_GPU_env/lib/python3.12/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# ResourceExhaustedError: Graph execution error:
#
# Detected at node StatefulPartitionedCall defined at (most recent call last):
#   File "/opt/tljh/user/envs/BME342_GPU_env/lib/python3.12/runpy.py", line 198, in _run_module_as_main
#
#   File "/opt/tljh/user/envs/BME342_GPU_env/lib/python3.12/runpy.py", line 88, in _run_code
#
#   File "/opt/tljh/user/envs/BME342_GPU_env/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#
#   File "/opt/tljh/user/envs/BME342_GPU_env/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#
#   File "/opt/tljh/user/envs/BME342_GPU_env/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 739, in start
#
#   File "/opt/tljh/user/envs/BME342_GPU_env/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 205, in start
#
#   File "/opt/tljh/user/envs/BME342_GPU_env/lib/python3.12/asyncio/base_events.py", line 641, in run_forever
#
#   File "/opt/tljh/user/envs/BME342_GPU_env/lib/python3.12/asyncio/base_events.py", line 1986, in _run_once
#
#   File "/opt/tljh/user/envs/BME342_GPU_env/lib/python3.12/asyncio/events.py", line 88, in _run
#
#   File "/opt/tljh/user/envs/BME342_GPU_env/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#
#   File "/opt/tljh/user/envs/BME342_GPU_env/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#
#   File "/opt/tljh/user/envs/BME342_GPU_env/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#
#   File "/opt/tljh/user/envs/BME342_GPU_env/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#
#   File "/opt/tljh/user/envs/BME342_GPU_env/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#
#   File "/opt/tljh/user/envs/BME342_GPU_env/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#
#   File "/opt/tljh/user/envs/BME342_GPU_env/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#
#   File "/opt/tljh/user/envs/BME342_GPU_env/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3075, in run_cell
#
#   File "/opt/tljh/user/envs/BME342_GPU_env/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3130, in _run_cell
#
#   File "/opt/tljh/user/envs/BME342_GPU_env/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#
#   File "/opt/tljh/user/envs/BME342_GPU_env/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3334, in run_cell_async
#
#   File "/opt/tljh/user/envs/BME342_GPU_env/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3517, in run_ast_nodes
#
#   File "/opt/tljh/user/envs/BME342_GPU_env/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#
#   File "/tmp/ipykernel_716392/509609910.py", line 1, in <module>
#
#   File "/opt/tljh/user/envs/BME342_GPU_env/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py", line 117, in error_handler
#
#   File "/opt/tljh/user/envs/BME342_GPU_env/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py", line 510, in predict
#
#   File "/opt/tljh/user/envs/BME342_GPU_env/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py", line 208, in one_step_on_data_distributed
#
# Out of memory while trying to allocate 358220648 bytes.
# 	 [[{{node StatefulPartitionedCall}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [Op:__inference_one_step_on_data_distributed_3010]

# %%
X_test[0].shape
# Out:
# (224, 224, 46)

# %% [markdown]
# ### t-SNE on input data with 46 channels
